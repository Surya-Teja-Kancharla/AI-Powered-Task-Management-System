# %%
# !pip install ctgan
# Out:
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 73.8/73.8 kB 3.4 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 363.4/363.4 MB 4.1 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 13.8/13.8 MB 58.5 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 24.6/24.6 MB 46.1 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 883.7/883.7 kB 27.9 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 664.8/664.8 MB 3.0 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 211.5/211.5 MB 5.3 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 56.3/56.3 MB 10.9 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 127.9/127.9 MB 7.3 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 207.5/207.5 MB 6.2 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 21.1/21.1 MB 85.1 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 1.9/1.9 MB 68.5 MB/s eta 0:00:00
# ...

# %%
from ctgan import CTGAN
from ctgan import load_demo

# %%
real_data = load_demo()

# %%
real_data.head()
# Out:
#    age         workclass  fnlwgt  education  education-num  \
# 0   39         State-gov   77516  Bachelors             13
# 1   50  Self-emp-not-inc   83311  Bachelors             13
# 2   38           Private  215646    HS-grad              9
# 3   53           Private  234721       11th              7
# 4   28           Private  338409  Bachelors             13
#
#        marital-status         occupation   relationship   race     sex  \
# 0       Never-married       Adm-clerical  Not-in-family  White    Male
# 1  Married-civ-spouse    Exec-managerial        Husband  White    Male
# 2            Divorced  Handlers-cleaners  Not-in-family  White    Male
# 3  Married-civ-spouse  Handlers-cleaners        Husband  Black    Male
# 4  Married-civ-spouse     Prof-specialty           Wife  Black  Female
#
#    capital-gain  capital-loss  hours-per-week native-country income
# 0          2174             0              40  United-States  <=50K
# ...

# %%
import pandas as pd

data = pd.read_csv('Task_data.csv')

# %%
data.head()
# Out:
#      Task_ID                                   Task_Description  \
# 0  TASK-1000             Stand stop nice new long type several.
# 1  TASK-1001            Have fear drug boy find point such ago.
# 2  TASK-1002  Next deep expert report pressure today out las...
# 3  TASK-1003             Few hotel or open whose operation how.
# 4  TASK-1004  Administration pass deal even ever family real...
#
#   Priority_Level  Task_Status Task_Deadline Assigned_To          Task_Origin  \
# 0           High    Completed    07-06-2025     USER-22  Internal Initiative
# 1           High  In Progress    04-06-2025     USER-43  Internal Initiative
# 2           High    Completed    15-06-2025      USER-9  Internal Initiative
# 3           High      Pending    23-05-2025      USER-5  Internal Initiative
# 4           High    Completed    12-06-2025     USER-47  Internal Initiative
#
#        Task_Type  Estimated_Completion_Time  Actual_Completion_Time  ...  \
# ...

# %%
ctgan = CTGAN(epochs=10)
ctgan.fit(data, data.columns)

# %%
synthetic_data = ctgan.sample(1000)

# %%
combined_data = pd.concat([data, synthetic_data], ignore_index=True)

# %%
combined_data.to_csv('New_Task_data.csv', index=False)

# %%
combined_data.head()
# Out:
#      Task_ID                                   Task_Description  \
# 0  TASK-1000             Stand stop nice new long type several.
# 1  TASK-1001            Have fear drug boy find point such ago.
# 2  TASK-1002  Next deep expert report pressure today out las...
# 3  TASK-1003             Few hotel or open whose operation how.
# 4  TASK-1004  Administration pass deal even ever family real...
#
#   Priority_Level  Task_Status Task_Deadline Assigned_To          Task_Origin  \
# 0           High    Completed    07-06-2025     USER-22  Internal Initiative
# 1           High  In Progress    04-06-2025     USER-43  Internal Initiative
# 2           High    Completed    15-06-2025      USER-9  Internal Initiative
# 3           High      Pending    23-05-2025      USER-5  Internal Initiative
# 4           High    Completed    12-06-2025     USER-47  Internal Initiative
#
#        Task_Type  Estimated_Completion_Time  Actual_Completion_Time  ...  \
# ...

# %%
combined_data.shape
# Out:
# (1200, 30)
