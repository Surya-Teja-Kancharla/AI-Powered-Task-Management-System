# %%
import pandas as pd

data = pd.read_csv('New_Task_data.csv')

# %%
data.head()
# Out:
#      Task_ID                                   Task_Description  Task_Status  \
# 0  TASK-1000             Stand stop nice new long type several.    Completed
# 1  TASK-1001            Have fear drug boy find point such ago.  In Progress
# 2  TASK-1002  Next deep expert report pressure today out las...    Completed
# 3  TASK-1003             Few hotel or open whose operation how.      Pending
# 4  TASK-1004  Administration pass deal even ever family real...    Completed
#
#   Task_Deadline Assigned_To          Task_Origin      Task_Type  \
# 0    07-06-2025     USER-22  Internal Initiative    Development
# 1    04-06-2025     USER-43  Internal Initiative        Testing
# 2    15-06-2025      USER-9  Internal Initiative        Testing
# 3    23-05-2025      USER-5  Internal Initiative    Development
# 4    12-06-2025     USER-47  Internal Initiative  Documentation
#
#    Estimated_Completion_Time  Actual_Completion_Time  User_ID  ...  \
# ...

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1200 entries, 0 to 1199
# Data columns (total 30 columns):
#  #   Column                     Non-Null Count  Dtype
# ---  ------                     --------------  -----
#  0   Task_ID                    1200 non-null   object
#  1   Task_Description           1200 non-null   object
#  2   Task_Status                1200 non-null   object
#  3   Task_Deadline              1200 non-null   object
#  4   Assigned_To                1200 non-null   object
#  5   Task_Origin                1200 non-null   object
#  6   Task_Type                  1200 non-null   object
#  7   Estimated_Completion_Time  1200 non-null   int64
#  8   Actual_Completion_Time     1200 non-null   int64
#  9   User_ID                    1200 non-null   object
#  10  User_Name                  1200 non-null   object
#  11  Role                       1200 non-null   object
#  12  Workload                   1200 non-null   int64
# ...

# %%
data.describe()
# Out:
#        Estimated_Completion_Time  Actual_Completion_Time     Workload  \
# count                1200.000000             1200.000000  1200.000000
# mean                   10.594167               12.927500     5.489167
# std                     5.812712                6.757857     2.849266
# min                     1.000000                1.000000     1.000000
# 25%                     6.000000                7.000000     3.000000
# 50%                    10.000000               13.000000     5.500000
# 75%                    16.000000               19.000000     8.000000
# max                    20.000000               25.000000    10.000000
#
#        Productivity_Score  Stress_Level  Historical_Delays  Urgency_Score  \
# count         1200.000000   1200.000000        1200.000000    1200.000000
# mean             0.754500      4.898467           2.588333       0.494533
# std              0.145038      2.922303           1.706739       0.290645
# ...

# %%
data.columns
# Out:
# Index(['Task_ID', 'Task_Description', 'Task_Status', 'Task_Deadline',
#        'Assigned_To', 'Task_Origin', 'Task_Type', 'Estimated_Completion_Time',
#        'Actual_Completion_Time', 'User_ID', 'User_Name', 'Role', 'Workload',
#        'Team_Name', 'Productivity_Score', 'Feedback_Text', 'Sentiment_Score',
#        'Communication_Channel', 'Stress_Level', 'Historical_Delays',
#        'Task_Dependencies', 'Bottleneck_Flag', 'Urgency_Score',
#        'Optimal_Assignment', 'Forecast_Completion_Time', 'Deadline_Adherence',
#        'Task_Completion_Trend', 'Performance_Indicator',
#        'Shared_Taskboard_Updates', 'Priority_Level'],
#       dtype='object')

# %%
import seaborn as sns
import matplotlib.pyplot as plt

sns.countplot(data['Priority_Level'])
plt.show()

# %%
print(data['Priority_Level'].value_counts())
# Out:
# Priority_Level
# High      448
# Medium    403
# Low       349
# Name: count, dtype: int64
